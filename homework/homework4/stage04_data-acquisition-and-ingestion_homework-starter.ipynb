# %% [markdown]
# # Homework Starter — Stage 04: Data Acquisition and Ingestion
# Name: Jiayi CHEN
# Date: 2026/08/20
#
# ## Objectives
# - API ingestion with secrets in `.env`
# - Scrape a permitted public table
# - Validate and save raw data to `data/raw/`

# %%
# --- packages this notebook needs (uncomment and run once, then re-comment) ---
# !pip install pandas
# !pip install requests
# !pip install yfinance
# !pip install python-dotenv
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: pandas in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: requests in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests) (3.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests) (2026.7.22)
# Requirement already satisfied: yfinance in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (1.6.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (4.15.0)
# Requirement already satisfied: curl_cffi>=0.15 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (0.16.0)
# Requirement already satisfied: lxml>=4.9.0 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (6.1.1)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: numpy>=1.16.5 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (2.2.6)
# Requirement already satisfied: pandas>=1.3.0 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: peewee>=3.16.2 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (4.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (4.11.3)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (7.35.1)
# Requirement already satisfied: pytz>=2022.5 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (2026.3.post1)
# Requirement already satisfied: requests>=2.31 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (2.34.2)
# Requirement already satisfied: websockets>=13.0 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (16.1.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.16.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from curl_cffi>=0.15->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from curl_cffi>=0.15->yfinance) (2026.7.22)
# Requirement already satisfied: pycparser in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2026.3)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.7.0)
# Requirement already satisfied: python-dotenv in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: beautifulsoup4 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from beautifulsoup4) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from beautifulsoup4) (4.16.0)

# %%
# --- files this notebook needs (run me first - I only report, I change nothing) ---
from pathlib import Path

ROOT = Path.cwd()          # notebooks are meant to be run from their own folder
CHECKS = [
    (".env", "NEEDED", "YOU create this: copy .env.example to .env. Missing = no error, but the config demo silently shows nothing"),
    (".env.example", "NEEDED", "shipped with this stage - the template you copy to .env"),
]

print(f"Looking in: {ROOT}\n")
missing = 0
for rel, kind, note in CHECKS:
    here = (ROOT / rel).exists()
    if not here and kind == "NEEDED":
        missing += 1
    print(f"  [{'OK ' if here else 'MISS'}]  {kind:<8}  {rel:<34}  {note}")

if missing:
    print(f"\n{missing} needed file(s) missing. Put them at the paths above, relative to:\n  {ROOT}")
    print("If that folder looks wrong, you are running the notebook from the wrong place.")
else:
    print("\nAll needed files present.")
# Out:
# Looking in: /Users/chenjiayi/bootcamp_Jiayi_Chen/homework/homework4
#
#   [OK ]  NEEDED    .env                                YOU create this: copy .env.example to .env. Missing = no error, but the config demo silently shows nothing
#   [OK ]  NEEDED    .env.example                        shipped with this stage - the template you copy to .env
#
# All needed files present.

# %%
import os, pathlib, datetime as dt
import requests
import pandas as pd
from bs4 import BeautifulSoup
from dotenv import load_dotenv

RAW = pathlib.Path('data/raw'); RAW.mkdir(parents=True, exist_ok=True)
load_dotenv(); print('ALPHAVANTAGE_API_KEY loaded?', bool(os.getenv('ALPHAVANTAGE_API_KEY')))
# Out:
# ALPHAVANTAGE_API_KEY loaded? True

# %% [markdown]
# ## Helpers (use or modify)

# %%
def ts():
    return dt.datetime.now().strftime('%Y%m%d-%H%M%S')

def save_csv(df: pd.DataFrame, prefix: str, **meta):
    mid = '_'.join([f"{k}-{v}" for k,v in meta.items()])
    path = RAW / f"{prefix}_{mid}_{ts()}.csv"
    df.to_csv(path, index=False)
    print('Saved', path)
    return path

def validate(df: pd.DataFrame, required):
    missing = [c for c in required if c not in df.columns]
    return {'missing': missing, 'shape': df.shape, 'na_total': int(df.isna().sum().sum())}

# %% [markdown]
# ## Part 1 — API Pull (Required)
# Choose an endpoint (e.g., Alpha Vantage or use `yfinance` fallback).

# %%
SYMBOL = 'AAPL'
USE_ALPHA = bool(os.getenv('ALPHAVANTAGE_API_KEY'))
if USE_ALPHA:
    url = 'https://www.alphavantage.co/query'
    params = {'function':'TIME_SERIES_DAILY','symbol':SYMBOL,'outputsize':'compact','apikey':os.getenv('ALPHAVANTAGE_API_KEY')}
    r = requests.get(url, params=params, timeout=30)
    r.raise_for_status()
    js = r.json()
    # Alpha Vantage answers 200 OK with a prose blob when the free daily cap (25 calls)
    # is hit, so check for the series rather than trusting the status code.
    key = [k for k in js if 'Time Series' in k]
    if not key:
        print('Alpha Vantage returned no series:', str(list(js.values())[0])[:150])
        USE_ALPHA = False

if USE_ALPHA:
    df_api = pd.DataFrame(js[key[0]]).T.reset_index().rename(columns={'index':'date','4. close':'close'})[['date','close']]
    df_api['date'] = pd.to_datetime(df_api['date']); df_api['close'] = pd.to_numeric(df_api['close'])

if not USE_ALPHA:
    import yfinance as yf
    df_api = yf.download(SYMBOL, period='3mo', interval='1d', auto_adjust=False,
                         multi_level_index=False).reset_index()[['Date','Close']]
    df_api.columns = ['date','close']

v_api = validate(df_api, ['date','close']); v_api

# %%
_ = save_csv(df_api.sort_values('date'), prefix='api', source='alpha' if USE_ALPHA else 'yfinance', symbol=SYMBOL)

# %% [markdown]
# ## Part 2 — Scrape a Public Table (Required)
# Replace `SCRAPE_URL` with a permitted page containing a simple table.

# %%
SCRAPE_URL = 'https://example.com/markets-table'  # TODO: replace with permitted page
headers = {'User-Agent':'AFE-Homework/1.0'}
try:
    resp = requests.get(SCRAPE_URL, headers=headers, timeout=30); resp.raise_for_status()
    soup = BeautifulSoup(resp.text, 'html.parser')
    rows = [[c.get_text(strip=True) for c in tr.find_all(['th','td'])] for tr in soup.find_all('tr')]
    header, *data = [r for r in rows if r]
    df_scrape = pd.DataFrame(data, columns=header)
except Exception as e:
    print('Scrape failed, using inline demo table:', e)
    html = '<table><tr><th>Ticker</th><th>Price</th></tr><tr><td>AAA</td><td>101.2</td></tr></table>'
    soup = BeautifulSoup(html, 'html.parser')
    rows = [[c.get_text(strip=True) for c in tr.find_all(['th','td'])] for tr in soup.find_all('tr')]
    header, *data = [r for r in rows if r]
    df_scrape = pd.DataFrame(data, columns=header)

if 'Price' in df_scrape.columns:
    df_scrape['Price'] = pd.to_numeric(df_scrape['Price'], errors='coerce')
v_scrape = validate(df_scrape, list(df_scrape.columns)); v_scrape

# %%
_ = save_csv(df_scrape, prefix='scrape', site='example', table='markets')

# %% [markdown]
# ## Documentation
# - API Source: (URL/endpoint/params)
# - Scrape Source: (URL/table description)
# - Assumptions & risks: (rate limits, selector fragility, schema changes)
# - Confirm `.env` is not committed.
